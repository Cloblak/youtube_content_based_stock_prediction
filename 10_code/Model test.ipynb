# %%
import pandas as pd
df = pd.read_csv("Cleaned_Sent_Data_16MAR_v3.gz")

# %%
df
# Out:
#     Unnamed: 0        Date  videoTitleSentimentScore_pos  \
# 0            0  2020-10-02                      0.081317
# 1            1  2020-10-03                      0.059800
# 2            2  2020-10-04                      0.066000
# 3            3  2020-10-05                      0.071018
# 4            4  2020-10-06                      0.066353
# ..         ...         ...                           ...
# 87          87  2021-02-15                      0.034680
# 88          88  2021-02-16                      0.040633
# 89          89  2021-02-18                      0.046834
# 90          90  2021-02-19                      0.033890
# 91          91  2021-02-20                      0.045380
#
#     videoTitleSentimentScore_neg  captionSentimentScore_pos  \
# 0                       0.099751                   0.102556
# 1                       0.065880                   0.116100
# 2                       0.059480                   0.110600
# 3                       0.065469                   0.110771
# 4                       0.069018                   0.110309
# ..                           ...                        ...
# 87                      0.077251                   0.107473
# 88                      0.051960                   0.102418
# 89                      0.058583                   0.101794
# 90                      0.069657                   0.097573
# 91                      0.073320                   0.103120
#
#     captionSentimentScore_neg  num_days_since_pub  viewcounts_weighted  \
# 0                    0.036249           17.925926         71814.282680
# 1                    0.034660           35.600000         71921.099664
# 2                    0.035320           21.680000         66084.953130
# 3                    0.031495           19.829091         61208.718514
# 4                    0.031280           19.432727         72276.063635
# ..                        ...                 ...                  ...
# 87                   0.031818          115.607273         13347.728400
# 88                   0.032844          120.298182         25551.254491
# 89                   0.032863          119.245714         16224.086329
# 90                   0.031320          113.623333         19150.754564
# 91                   0.034700          101.600000         41163.221800
#
#     like_count_weighted  like_dislike_ratio  weighted_like_dislike_ratio  \
# 0           3271.401019            0.969752                     0.969752
# 1           3523.220911            0.969585                     0.969585
# 2           3030.285674            0.972772                     0.972772
# 3           3150.355807            0.971021                     0.971021
# 4           3948.601316            0.972598                     0.972598
# ..                  ...                 ...                          ...
# 87           693.672590            0.956675                     0.956675
# 88          1678.468242            0.960266                     0.960266
# 89           939.047614            0.954441                     0.954441
# 90          1316.566845            0.958693                     0.958693
# 91          3604.290577            0.958253                     0.958253
#
#     like_dislike_ratio_by_viewcounts_weighted       index  percent_change  \
# 0                                69921.826086  2020-10-02        0.044362
# 1                                70150.404005  2020-10-03        0.041791
# 2                                64444.365869  2020-10-04        0.022541
# 3                                59725.066775  2020-10-05        0.013192
# 4                                70807.388299  2020-10-06       -0.022469
# ..                                        ...         ...             ...
# 87                               12957.795705  2021-02-15       -0.007472
# 88                               25040.842574  2021-02-16       -0.012718
# 89                               15837.504011  2021-02-18       -0.042660
# 90                               18586.708998  2021-02-19       -0.044162
# 91                               40312.584142  2021-02-20       -0.052860
#
#    action _merge
# 0     buy   both
# 1     buy   both
# 2    hold   both
# 3    hold   both
# 4    hold   both
# ..    ...    ...
# 87   hold   both
# 88   hold   both
# 89   sell   both
# 90   sell   both
# 91   sell   both
#
# [92 rows x 16 columns]

# %%
from sklearn import preprocessing
import numpy as np
scaler = preprocessing.StandardScaler().fit(X_train)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')

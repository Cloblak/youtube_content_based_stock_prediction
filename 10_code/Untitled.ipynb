# %%
import pandas as pd
df = pd.read_csv("../00_data/nvidia_caption_data_21FEB.gz",compression='gzip')

# %%
df = df.drop(['Unnamed: 0','Unnamed: 0.1','videoID','datePub'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16618 entries, 0 to 16617
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   searchedDate   16618 non-null  object
#  1   VideoTitle     16618 non-null  object
#  2   channelTitle   16618 non-null  object
#  3   viewCount      16618 non-null  int64
#  4   likeCount      16618 non-null  int64
#  5   dislikeCount   16618 non-null  object
#  6   captionString  16268 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 908.9+ KB

# %%
df
# Out:
#                                             searchedDate  \
# 0                             2020-10-02 01:45:21.553469
# 1                             2020-10-02 01:45:22.351801
# 2                             2020-10-02 01:45:23.252012
# 3                             2020-10-02 01:45:23.922084
# 4                             2020-10-02 01:45:24.592244
# ...                                                  ...
# 16613  Jim Cramer breaks down Nvidia's acquisition of...
# 16614          Making Nvidia’s CEO mad - RTX 3090 Review
# 16615  NVIDIA might ACTUALLY be EVIL... - WAN Show De...
# 16616           The GPU NVIDIA didn’t tell anyone about…
# 16617                                    Nvidia Gave Up!
#
#                                               VideoTitle     channelTitle  \
# 0      2x NVIDIA RTX 3090 SLI Benchmarks: 500FPS, 700...     Gamers Nexus
# 1                NVIDIA GeForce Special Event Livestream              IGN
# ...

# %%
df['date'] = pd.to_datetime(df['searchedDate'])
df['date'].apply(lambda x: x.date())
df=df.drop(['searchedDate'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2084         try:
# -> 2085             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2086             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-343678d27237> in <module>
# ----> 1 df['date'] = pd.to_datetime(df['searchedDate'])
#       2 df['date'].apply(lambda x: x.date())
# ...

# %%
df.shape

# %%
df.head()

# %%
# How many date do we have
# Here we have 711 date. We have ~23 videos about Nvidia each day.
df['date'].nunique()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.suptitle("Frequency plot of date", fontsize=16)
sns.histplot(data=df, x="date")

# %%
# Do we aggregate the date? So each row can represent the total videos in that day? If so, we only have 711 rows
# for Nvidia and the features we have so far is 6. And we want predict the stock price for Nvidia goes up or down or 
# stay the same for that day.

# %%
# %load_ext lab_black

import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta, date
import matplotlib.pyplot as plt
from math import log
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
#####
# Load and Explore the Data
#####
cleaned_data_df = pd.read_csv("../00_data/Cleaned_Data_22MAR.gz", compression="gzip")
hr_merged_df = pd.read_csv("Feature_label_nvda.csv")

# %%
cleaned_data_df[cleaned_data_df["VideoTitle"].isna()]["videoID"].nunique()
# Out:
# 0

# %%
cleaned_data_df["videoID"].nunique()
# Out:
# 450

# %%
cleaned_data_df
# Out:
#        Unnamed: 0  Index      videoID                    datePub  \
# 0               0      0  y4fb_R5Ogw0  2020-10-01 05:16:02+00:00
# 1               1      1  ALEXVtnNEwA  2020-09-01 17:15:57+00:00
# 2               2      2  E98hC9e__Xs  2020-09-01 16:42:07+00:00
# 3               3      3  nMns8t4OhI0  2020-09-30 23:00:06+00:00
# 4               4      4  AG_ZHi3tuyk  2020-09-16 12:59:59+00:00
# ...           ...    ...          ...                        ...
# 20788       20788     20  AG_ZHi3tuyk  2020-09-16 12:59:59+00:00
# 20789       20789     21  3dJhDqLjPN0  2021-02-24 21:59:34+00:00
# 20790       20790     22  H1DApIvOCMw  2021-02-26 17:35:37+00:00
# 20791       20791     23  Y5J2bgXiK9g  2021-03-09 17:00:10+00:00
# 20792       20792     24  HZigkcTxRo0  2021-02-25 03:01:00+00:00
#
#                            searchedDate  \
# 0      2020-10-02 01:45:21.553469+00:00
# 1      2020-10-02 01:45:22.351801+00:00
# 2      2020-10-02 01:45:23.252012+00:00
# 3      2020-10-02 01:45:23.922084+00:00
# 4      2020-10-02 01:45:24.592244+00:00
# ...                                 ...
# 20788  2021-03-19 18:03:20.670031+00:00
# 20789  2021-03-19 18:03:21.320922+00:00
# 20790  2021-03-19 18:03:21.788746+00:00
# 20791  2021-03-19 18:03:22.387116+00:00
# 20792  2021-03-19 18:03:22.919039+00:00
#
#                                               VideoTitle  \
# 0      2x NVIDIA RTX 3090 SLI Benchmarks: 500FPS, 700...
# 1                NVIDIA GeForce Special Event Livestream
# 2      NVIDIA GeForce RTX 30 Series | Official Launch...
# 3                 NVIDIA Responds to RTX 3080 Crashes...
# 4                Nvidia, you PROMISED! - RTX 3080 Review
# ...                                                  ...
# 20788            Nvidia, you PROMISED! - RTX 3080 Review
# 20789  NVIDIA (NVDA) Stock Analysis - Q4 Earnings + I...
# 20790          My SALTY Review of the NVIDIA RTX 3060...
# 20791                  Should Nvidia Stop Selling 3060s?
# 20792                        Nvidia’s plan ISN’T WORKING
#
#                channelTitle  viewCount  likeCount  dislikeCount  \
# 0              Gamers Nexus     367472      15701           260
# 1                       IGN     543115      16860           411
# 2            NVIDIA GeForce    1484075      54741          1135
# 3              JayzTwoCents     561238      27766           885
# 4           Linus Tech Tips    3391565     141852          3961
# ...                     ...        ...        ...           ...
# 20788       Linus Tech Tips    3741789     148430          4216
# 20789  The Investor Channel       7773        269             1
# 20790          JayzTwoCents    1013948      51773           702
# 20791             LMG Clips      53940       2238            33
# 20792            TechLinked    1394144     145393          4053
#
#                                            captionString
# 0      so this setup that you're seeing is what we ha...
# 1      b welcome to my kitchen i hope all of you are ...
# 2        Welcome to my kitchen. I hope all of you are...
# 3                                                    NaN
# 4      - The RTX 3080 is the most powerful GPU we've ...
# ...                                                  ...
# 20788  - The RTX 3080 is the most powerful GPU we've ...
# 20789  what is going on investors hopefully guys had ...
# 20790  with no parts markup and only a 75 build fee r...
# 20791  uh the you know the 30 80 eth mining wait isn'...
# 20792  - Techlinked number three, four, five. -  Yeah...
#
# [20793 rows x 11 columns]

# %%
#####
# Normalize the data
#####

from sklearn import preprocessing

columns = hr_merged_df.columns

# #Print columns to refernce for normlization
# for i in range(len(columns)):
#     print(columns[i])
#     pass

column_names_to_normalize = [
    "viewCount",
    "likeCount",
    "dislikeCount",
    "videoTitleSentimentScore_pos",
    "videoTitleSentimentScore_neg",
    "captionSentimentScore_pos",
    "captionSentimentScore_neg",
    "captionSentimentScore_com",
    "videoTitleSentimentScore_com",
    "num_days_since_pub",
    "viewcounts_weighted",
    "like_count_weighted",
    "dislike_count_weighted",
    "like_dislike_ratio",
    "weighted_like_dislike_ratio",
    "like_dislike_ratio_by_viewcounts_weighted",
]

hr_merged_df_normal = hr_merged_df.copy()

# scaler = preprocessing.StandardScaler().fit(X_train_ohe[column_names_to_normalize])
# X_train_ohe[column_names_to_normalize] = scaler.fit_transform(
#     X_train_ohe[column_names_to_normalize]
# )
# X_test_ohe[column_names_to_normalize] = scaler.fit_transform(
#     X_test_ohe[column_names_to_normalize]
# )

min_max_scaler = preprocessing.MinMaxScaler().fit(
    hr_merged_df_normal[column_names_to_normalize]
)

hr_merged_df_normal[column_names_to_normalize] = min_max_scaler.fit_transform(
    hr_merged_df_normal[column_names_to_normalize]
)
# Out:
# Unnamed: 0
# Time
# viewCount
# likeCount
# dislikeCount
# videoTitleSentimentScore_pos
# videoTitleSentimentScore_neg
# captionSentimentScore_pos
# captionSentimentScore_neg
# captionSentimentScore_com
# videoTitleSentimentScore_com
# num_days_since_pub
# viewcounts_weighted
# like_count_weighted
# dislike_count_weighted
# like_dislike_ratio
# weighted_like_dislike_ratio
# like_dislike_ratio_by_viewcounts_weighted
# weekday
# price
# future_price
# percent_change

# %%
hr_merged_df_normal["Time"] = pd.to_datetime(
    hr_merged_df_normal["Time"], format="%Y-%m-%d %H:%M", utc=True
).dt.date

# %%
hr_merged_df_normal["product_videosent"] = (
    hr_merged_df_normal["videoTitleSentimentScore_pos"]
    * hr_merged_df_normal["videoTitleSentimentScore_neg"]
)

# %%
hr_merged_df_normal.head()
# Out:
#    Unnamed: 0        Time  viewCount  likeCount  dislikeCount  \
# 0           0  2020-10-02   0.692394   0.661333      0.772710
# 1           1  2020-10-02   0.750596   0.724955      0.860548
# 2           2  2020-10-02   0.773689   0.754522      0.898270
# 3           3  2020-10-02   0.774107   0.755082      0.898994
# 4           4  2020-10-02   0.775810   0.756410      0.901371
#
#    videoTitleSentimentScore_pos  videoTitleSentimentScore_neg  \
# 0                      0.675801                      0.863367
# 1                      0.476651                      0.819578
# 2                      0.573833                      0.671084
# 3                      0.476651                      0.803916
# 4                      0.476651                      0.671084
#
#    captionSentimentScore_pos  captionSentimentScore_neg  \
# 0                   0.832389                   0.948602
# 1                   0.808907                   0.846591
# 2                   0.801642                   0.782197
# 3                   0.803538                   0.836174
# 4                   0.788692                   0.831439
#
#    captionSentimentScore_com  ...  like_count_weighted  \
# 0                   0.936326  ...             0.325562
# 1                   0.912130  ...             0.259327
# 2                   0.912021  ...             0.262472
# 3                   0.912061  ...             0.264972
# 4                   0.911852  ...             0.264391
#
#    dislike_count_weighted  like_dislike_ratio  weighted_like_dislike_ratio  \
# 0                0.496561            0.838936                     0.838936
# 1                0.457250            0.781887                     0.781887
# 2                0.464198            0.714035                     0.714035
# 3                0.467953            0.783524                     0.783524
# 4                0.467980            0.767230                     0.767230
#
#    like_dislike_ratio_by_viewcounts_weighted  weekday      price  \
# 0                                   0.414371        4  522.47998
# 1                                   0.311746        4  522.47998
# 2                                   0.316413        4  522.47998
# 3                                   0.318079        4  522.47998
# 4                                   0.319375        4  522.47998
#
#    future_price  percent_change  product_videosent
# 0    545.700012        4.444195           0.583465
# 1    545.700012        4.444195           0.390653
# 2    545.700012        4.444195           0.385090
# 3    545.700012        4.444195           0.383187
# 4    545.700012        4.444195           0.319873
#
# [5 rows x 23 columns]

# %%
corr = hr_merged_df_normal.corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(22, 18))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(
    corr,
    mask=mask,
    cmap=cmap,
    vmax=0.3,
    center=0,
    square=True,
    linewidths=0.5,
    annot=True,
    cbar_kws={"shrink": 0.5},
)

# %%
hr_merged_df_normal.sample()
# Out:
#      Unnamed: 0                 Time  viewCount  likeCount  dislikeCount  \
# 587         587  2021-02-19 16:30:00   0.745021   0.763026      0.782251
#
#      videoTitleSentimentScore_pos  videoTitleSentimentScore_neg  \
# 587                      0.013042                      0.588253
#
#      captionSentimentScore_pos  captionSentimentScore_neg  \
# 587                   0.783639                   0.741477
#
#      captionSentimentScore_com  ...  viewcounts_weighted  like_count_weighted  \
# 587                   0.826049  ...             0.089196              0.10271
#
#      dislike_count_weighted  like_dislike_ratio  weighted_like_dislike_ratio  \
# 587                0.187792             0.42117                      0.42117
#
#      like_dislike_ratio_by_viewcounts_weighted  weekday       price  \
# 587                                   0.087941        4  597.200012
#
#      future_price  percent_change
# 587     574.22998       -3.846288
#
# [1 rows x 22 columns]

# %%
x = pd.DataFrame(hr_merged_df_normal.Time)
# print(full_joined_df["compound"])
y = pd.DataFrame(hr_merged_df_normal["videoTitleSentimentScore_com"])

# create figure and axis objects with subplots()
fig, ax = plt.subplots(figsize=(40, 10))
# make a plot

ax.plot(
    hr_merged_df_normal.Time,
    hr_merged_df_normal.percent_change,
    color="red",
    marker="o",
)
# set x-axis label
ax.set_xlabel("Date/Time", fontsize=14)
plt.xticks(rotation=45)
# set y-axis label
ax.set_ylabel("NVDA Price Percent Change", color="red", fontsize=14)
# twin object for two different y-axis on the sample plot
ax2 = ax.twinx()
# make a plot with different y-axis using second axis object

ax2.plot(
    hr_merged_df_normal.Time,
    hr_merged_df_normal["videoTitleSentimentScore_com"],
    color="blue",
    marker="o",
)
ax2.set_ylabel("Video Title Compound Sentiment Score", color="blue", fontsize=14)


def find_weekend_indices(datetime_array):
    indices = []
    for i in range(len(datetime_array)):
        if datetime_array[i].weekday() >= 5:
            indices.append(i)
    return indices


indices = find_weekend_indices(hr_merged_df_normal.Time)
# print(indices)

sat = hr_merged_df_normal.Time[indices[0]]
sun = hr_merged_df_normal.Time[indices[0]] + timedelta(days=1)
for i in range(
    round(
        int(
            (
                hr_merged_df_normal.Time[indices[-1]]
                - hr_merged_df_normal.Time[indices[0]]
            ).days
        )
        / 7
    )
    + 2
):
    ax.axvspan(sat, sun, alpha=0.5, color="gray")
    sat += timedelta(days=7)
    sun += timedelta(days=7)

plt.show()
# save the plot as a file
fig.savefig(
    "../20_graphics/NVDA_Sentiment_Stock_ComparisonPlot.jpeg",
    format="jpeg",
    dpi=200,
    bbox_inches="tight",
)

# %%
#####
# Distrpution Plots
#####

# %%
fig, ax = plt.subplots(figsize=(30, 10))
ax.hist(hr_merged_df_normal["videoTitleSentimentScore_pos"], color="blue", bins=25)
ax.hist(
    hr_merged_df_normal["videoTitleSentimentScore_neg"], color="red", alpha=0.5, bins=25
)
ax.hist(
    hr_merged_df_normal["videoTitleSentimentScore_com"],
    color="green",
    alpha=0.5,
    bins=25,
)
# Out:
# (array([  2.,  10.,   8.,  20.,  65.,  53.,  70.,  49.,  47.,  85.,  44.,
#          37.,   6.,   1.,   0.,   2.,   0.,   4.,  30., 103.,  57.,  26.,
#          16.,   2.,   2.]),
#  array([0.  , 0.04, 0.08, 0.12, 0.16, 0.2 , 0.24, 0.28, 0.32, 0.36, 0.4 ,
#         0.44, 0.48, 0.52, 0.56, 0.6 , 0.64, 0.68, 0.72, 0.76, 0.8 , 0.84,
#         0.88, 0.92, 0.96, 1.  ]),
#  <a list of 25 Patch objects>)

# %%
fig, ax = plt.subplots(figsize=(30, 10))
ax.hist(log(hr_merged_df_normal["videoTitleSentimentScore_pos"]), color="blue", bins=25)
ax.hist(
    hr_merged_df_normal["videoTitleSentimentScore_neg"],
    color="red",
    alpha=0.5,
    bins=25,
)
ax.hist(
    hr_merged_df_normal["videoTitleSentimentScore_com"],
    color="green",
    alpha=0.5,
    bins=25,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-cc243ca315e3> in <module>
#       1 fig, ax = plt.subplots(figsize=(30, 10))
# ----> 2 ax.hist(log(hr_merged_df_normal["videoTitleSentimentScore_pos"]), color="blue", bins=25)
#       3 ax.hist(
#       4     hr_merged_df_normal["videoTitleSentimentScore_neg"],
#       5     color="red",
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     127         if len(self) == 1:
#     128             return converter(self.iloc[0])
# --> 129         raise TypeError(f"cannot convert the series to {converter}")
#     130
#     131     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
fig, ax = plt.subplots(figsize=(30, 10))

ax.scatter(
    (
        hr_merged_df_normal["videoTitleSentimentScore_pos"]
        * hr_merged_df_normal["videoTitleSentimentScore_neg"]
        * hr_merged_df_normal["videoTitleSentimentScore_com"]
    ),
    hr_merged_df_normal.percent_change,
    color="red",
    marker="o",
)
# set x-axis label
ax.set_xlabel("Video Title Sentiment", fontsize=14)
plt.xticks(rotation=45)
# set y-axis label
ax.set_ylabel("NVDA Price Percent Change +24 Hours", color="red", fontsize=14)
plt.title("Video Title Neg/Pos", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Video Title Neg/Pos')

# %%
fig, ax = plt.subplots(figsize=(30, 10))

ax.scatter(
    (hr_merged_df_normal["videoTitleSentimentScore_com"]),
    hr_merged_df_normal.percent_change,
    color="red",
    marker="o",
)
# set x-axis label
ax.set_xlabel("Video Title Sentiment", fontsize=14)
plt.xticks(rotation=45)
# set y-axis label
ax.set_ylabel("NVDA Price Percent Change +24 Hours", color="red", fontsize=14)
plt.title("Video Title Pos Only", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Video Title Pos Only')

# %%
fig, ax = plt.subplots(figsize=(30, 10))

ax.scatter(
    (
        hr_merged_df_normal["captionSentimentScore_neg"]
        * hr_merged_df_normal["captionSentimentScore_pos"]
    ),
    hr_merged_df_normal.percent_change,
    color="red",
    marker="o",
)
# set x-axis label
ax.set_xlabel("Video Title Sentiment", fontsize=14)
plt.xticks(rotation=45)
# set y-axis label
ax.set_ylabel("NVDA Price Percent Change +24 Hours", color="red", fontsize=14)
plt.title("Caption Neg/Pos", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Caption Neg/Pos')

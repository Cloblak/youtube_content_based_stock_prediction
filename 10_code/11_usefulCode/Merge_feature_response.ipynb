# %%
import pandas as pd

# %%
df = pd.read_csv('../00_data/test_nvidia_from_02APR_to_11APR.csv',index_col=0)
stock_price = pd.read_csv('test_response.csv',index_col=0)
extra_features = pd.read_csv('stock_price_APR12.csv',index_col=0)

# %%
df['Time'] = df.index

# %%
df.tail()
# Out:
#                            Index  viewCount  likeCount  dislikeCount  \
# searchedDate
# 2021-04-11 02:30:00+00:00   12.5  839496.48   45796.56       1024.32
# 2021-04-11 05:30:00+00:00   12.5  833420.96   45815.76       1029.16
# 2021-04-11 10:30:00+00:00   12.5  832181.56   45771.36       1023.76
# 2021-04-11 14:30:00+00:00   12.5  833051.36   45799.20       1025.80
# 2021-04-11 18:30:00+00:00   12.5  834170.48   45819.80       1026.96
#
#                            num_days_since_pub  viewcounts_weighted  \
# searchedDate
# 2021-04-11 02:30:00+00:00              128.16         15579.970880
# 2021-04-11 05:30:00+00:00              121.28         15757.242997
# 2021-04-11 10:30:00+00:00              120.88         15123.071909
# 2021-04-11 14:30:00+00:00              121.04         15332.041869
# 2021-04-11 18:30:00+00:00              121.44         15510.218025
#
#                            like_count_weighted  dislike_count_weighted  \
# searchedDate
# ...

# %%
stock_price.action.value_counts()
# Out:
# hold    2688
# buy     1056
# sell     870
# Name: action, dtype: int64

# %%
df['Time'] = df['Time'].apply(lambda x: x[:-6])

# %%
df.tail()

# %%
stock_price.head()

# %%
df = df.merge(stock_price,on='Time',how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 54
# Data columns (total 32 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Index                                             55 non-null     float64
#  1   viewCount                                         55 non-null     float64
#  2   likeCount                                         55 non-null     float64
#  3   dislikeCount                                      55 non-null     float64
#  4   num_days_since_pub                                55 non-null     float64
#  5   viewcounts_weighted                               55 non-null     float64
#  6   like_count_weighted                               55 non-null     float64
#  7   dislike_count_weighted                            55 non-null     float64
#  8   like_dislike_ratio                                55 non-null     float64
# ...

# %%
df
# Out:
#     Index   viewCount  likeCount  dislikeCount  num_days_since_pub  \
# 0    12.5   857090.08   44060.44    968.200000              123.24
# 1    12.5  1007232.96   50007.56   1136.760000              131.08
# 2    12.5   857715.44   44094.92    969.280000              123.28
# 3    12.5   776461.96   42458.44    950.125000              107.44
# 4    12.5   931010.28   48778.48   1088.880000              123.84
# 5    12.5   777551.40   42626.88    929.000000              114.92
# 6    12.5   926784.84   48544.32   1135.041667              121.48
# 7    12.5   919984.36   48205.40   1087.840000              122.48
# 8    12.5   921163.36   48306.52   1134.333333              122.84
# 9    12.5   924344.64   48508.24   1096.200000              123.08
# 10   12.5   910261.60   48741.96   1071.040000              123.32
# 11   12.5   911219.52   48786.96   1072.040000              123.36
# 12   12.5   913046.16   48879.56   1074.240000              123.44
# ...

# %%
df = df.merge(extra_features,on='Time',how='left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 0 to 54
# Data columns (total 38 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Index                                             55 non-null     float64
#  1   viewCount                                         55 non-null     float64
#  2   likeCount                                         55 non-null     float64
#  3   dislikeCount                                      55 non-null     float64
#  4   num_days_since_pub                                55 non-null     float64
#  5   viewcounts_weighted                               55 non-null     float64
#  6   like_count_weighted                               55 non-null     float64
#  7   dislike_count_weighted                            55 non-null     float64
#  8   like_dislike_ratio                                55 non-null     float64
# ...

# %%
df = df.drop("Index",axis=1)

# %%
df = df.reset_index()

# %%
df = df.dropna()

# %%
df = df.iloc[9:,].drop("Index",axis=1)
df = df.reset_index()

# %%
df = df.drop('level_0',axis=1)

# %%
df[['Time','action','percent_change_96']]
# Out:
#                    Time action  percent_change_96
# 0   2021-04-01 02:30:00    buy           3.521059
# 1   2021-04-01 05:30:00    buy           3.521059
# 2   2021-04-01 10:30:00   hold           1.539837
# 3   2021-04-01 14:30:00   hold           1.288127
# 4   2021-04-01 18:30:00   hold           1.226644
# 5   2021-04-02 02:30:00   hold           1.226644
# 6   2021-04-02 05:30:00   hold           1.226644
# 7   2021-04-02 10:30:00   hold           0.938976
# 8   2021-04-02 14:30:00   hold           0.676640
# 9   2021-04-02 18:30:00   hold           0.291290
# 10  2021-04-03 02:30:00   hold           0.291290
# 11  2021-04-03 05:30:00   hold           0.291290
# 12  2021-04-03 10:30:00   hold           1.043007
# 13  2021-04-03 14:30:00   hold           2.943575
# 14  2021-04-03 18:30:00   hold           2.353773
# 15  2021-04-04 02:30:00   hold           2.353773
# 16  2021-04-04 05:30:00   hold           2.353773
# 17  2021-04-04 10:30:00    buy           3.707052
# ...

# %%
df.action.value_counts()
# Out:
# buy     30
# hold    25
# Name: action, dtype: int64

# %%
df.to_csv("test.csv")

# %%
df

# %%
df.info()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(data=df,x=df.index,y='price')
